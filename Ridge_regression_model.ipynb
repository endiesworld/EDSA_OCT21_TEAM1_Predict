# %%
# Libraries for data loading, data manipulation and data visulisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr


# Libraries for data preparation and model building
# import *

# Setting global constants to ensure notebook results are reproducible
# PARAMETER_CONSTANT = ###

import warnings
warnings.filterwarnings('ignore')

# %%
#Load train data
df_train = pd.read_csv("df_train.csv", index_col=0)

# %%
#Brief view of data
df_train.head(5)
# Out:
#                   time  Madrid_wind_speed Valencia_wind_deg  Bilbao_rain_1h  \
# 0  2015-01-01 03:00:00           0.666667           level_5             0.0
# 1  2015-01-01 06:00:00           0.333333          level_10             0.0
# 2  2015-01-01 09:00:00           1.000000           level_9             0.0
# 3  2015-01-01 12:00:00           1.000000           level_8             0.0
# 4  2015-01-01 15:00:00           1.000000           level_7             0.0
#
#    Valencia_wind_speed  Seville_humidity  Madrid_humidity  Bilbao_clouds_all  \
# 0             0.666667         74.333333        64.000000                0.0
# 1             1.666667         78.333333        64.666667                0.0
# 2             1.000000         71.333333        64.333333                0.0
# 3             1.000000         65.333333        56.333333                0.0
# 4             1.000000         59.000000        57.000000                2.0
#
#    Bilbao_wind_speed  Seville_clouds_all  ...  Madrid_temp_max  \
# 0           1.000000                 0.0  ...       265.938000
# 1           1.000000                 0.0  ...       266.386667
# 2           1.000000                 0.0  ...       272.708667
# 3           1.000000                 0.0  ...       281.895219
# 4           0.333333                 0.0  ...       280.678437
#
#    Barcelona_temp  Bilbao_temp_min  Bilbao_temp  Barcelona_temp_min  \
# 0      281.013000       269.338615   269.338615          281.013000
# 1      280.561667       270.376000   270.376000          280.561667
# 2      281.583667       275.027229   275.027229          281.583667
# 3      283.434104       281.135063   281.135063          283.434104
# 4      284.213167       282.252063   282.252063          284.213167
#
#    Bilbao_temp_max Seville_temp_min  Madrid_temp  Madrid_temp_min  \
# 0       269.338615       274.254667   265.938000       265.938000
# 1       270.376000       274.945000   266.386667       266.386667
# 2       275.027229       278.792000   272.708667       272.708667
# 3       281.135063       285.394000   281.895219       281.895219
# 4       282.252063       285.513719   280.678437       280.678437
#
#    load_shortfall_3h
# 0        6715.666667
# 1        4171.666667
# 2        4274.666667
# 3        5075.666667
# 4        6620.666667
#
# [5 rows x 48 columns]

# %%
#function replacee_null_with_mean replace the null values in a dataframe column with its mean value    

def replace_null_with_mean(df, col):
    df_cols = df.columns
    if col not in df_cols:
        raise ValueError
        
    new_df = df.copy()
    mean_val = new_df[col].mean()
    
    def mean_value(val):
        if np.isnan(val) :
            return mean_val
        return val

    
    new_df[col] = new_df[col].apply(mean_value)
#     new_df[col].replace(np.NaN, mean_val)
    
    return new_df

# %%
improved_df = replace_null_with_mean(df_train, "Valencia_pressure")

# %%
# look at data statistics
improved_df['Valencia_pressure'].isna().sum()
# Out:
# 0

# %%
# function drop_columns accepts a dataframe, a turple of columns that should be droped, and returns a new dataframe
def drop_columns(df, cols):
    col_name = [col for col in df if col.endswith(cols)]
    accepted_col_name = [col for col in df if col not in col_name]
    df_modified = df[accepted_col_name]
    
    return df_modified

# %%
# Remove columns that will generally not affect the response from domain research of renewable energy 
cols_not_needed = ('clouds_all', 'weather_id', 'temp','temp_min')
improved_df = drop_columns(improved_df, cols_not_needed)
improved_df.shape
# Out:
# (8763, 31)

# %%
# convert time col to pandas datetime type
def conver_time(df, col):
    return pd.to_datetime(df['time'])
improved_df['time'] = conver_time(improved_df, 'time')
improved_df['time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# Converts columns with object type to numeric data type, and drops the first column
def object_converter(df):
    new_df = df.copy()
    cols = df.columns
    object_type = [col for col in cols if df[col].dtype == 'O']
    new_df = pd.get_dummies(df, columns= object_type,drop_first=True)
    return new_df

# %%
improved_df = object_converter(improved_df)
improved_df_2 = improved_df.copy() # Create a copy of the dataset, to enable modeling with two different dataset
improved_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8763 entries, 0 to 8762
# Data columns (total 62 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time                        8763 non-null   datetime64[ns]
#  1   Madrid_wind_speed           8763 non-null   float64
#  2   Bilbao_rain_1h              8763 non-null   float64
#  3   Valencia_wind_speed         8763 non-null   float64
#  4   Seville_humidity            8763 non-null   float64
#  5   Madrid_humidity             8763 non-null   float64
#  6   Bilbao_wind_speed           8763 non-null   float64
#  7   Bilbao_wind_deg             8763 non-null   float64
#  8   Barcelona_wind_speed        8763 non-null   float64
#  9   Barcelona_wind_deg          8763 non-null   float64
#  10  Seville_wind_speed          8763 non-null   float64
#  11  Barcelona_rain_1h           8763 non-null   float64
#  12  Seville_rain_1h             8763 non-null   float64
#  13  Bilbao_snow_3h              8763 non-null   float64
#  14  Barcelona_pressure          8763 non-null   float64
#  15  Seville_rain_3h             8763 non-null   float64
#  16  Madrid_rain_1h              8763 non-null   float64
#  17  Barcelona_rain_3h           8763 non-null   float64
#  18  Valencia_snow_3h            8763 non-null   float64
#  19  Bilbao_pressure             8763 non-null   float64
#  20  Valencia_pressure           8763 non-null   float64
#  21  Seville_temp_max            8763 non-null   float64
#  22  Madrid_pressure             8763 non-null   float64
#  23  Valencia_temp_max           8763 non-null   float64
#  24  Valencia_humidity           8763 non-null   float64
#  25  Barcelona_temp_max          8763 non-null   float64
#  26  Madrid_temp_max             8763 non-null   float64
#  27  Bilbao_temp_max             8763 non-null   float64
#  28  load_shortfall_3h           8763 non-null   float64
#  29  Valencia_wind_deg_level_10  8763 non-null   uint8
#  30  Valencia_wind_deg_level_2   8763 non-null   uint8
#  31  Valencia_wind_deg_level_3   8763 non-null   uint8
#  32  Valencia_wind_deg_level_4   8763 non-null   uint8
#  33  Valencia_wind_deg_level_5   8763 non-null   uint8
#  34  Valencia_wind_deg_level_6   8763 non-null   uint8
#  35  Valencia_wind_deg_level_7   8763 non-null   uint8
#  36  Valencia_wind_deg_level_8   8763 non-null   uint8
#  37  Valencia_wind_deg_level_9   8763 non-null   uint8
#  38  Seville_pressure_sp10       8763 non-null   uint8
#  39  Seville_pressure_sp11       8763 non-null   uint8
#  40  Seville_pressure_sp12       8763 non-null   uint8
#  41  Seville_pressure_sp13       8763 non-null   uint8
#  42  Seville_pressure_sp14       8763 non-null   uint8
#  43  Seville_pressure_sp15       8763 non-null   uint8
#  44  Seville_pressure_sp16       8763 non-null   uint8
#  45  Seville_pressure_sp17       8763 non-null   uint8
#  46  Seville_pressure_sp18       8763 non-null   uint8
#  47  Seville_pressure_sp19       8763 non-null   uint8
#  48  Seville_pressure_sp2        8763 non-null   uint8
#  49  Seville_pressure_sp20       8763 non-null   uint8
#  50  Seville_pressure_sp21       8763 non-null   uint8
#  51  Seville_pressure_sp22       8763 non-null   uint8
#  52  Seville_pressure_sp23       8763 non-null   uint8
#  53  Seville_pressure_sp24       8763 non-null   uint8
#  54  Seville_pressure_sp25       8763 non-null   uint8
#  55  Seville_pressure_sp3        8763 non-null   uint8
#  56  Seville_pressure_sp4        8763 non-null   uint8
#  57  Seville_pressure_sp5        8763 non-null   uint8
#  58  Seville_pressure_sp6        8763 non-null   uint8
#  59  Seville_pressure_sp7        8763 non-null   uint8
#  60  Seville_pressure_sp8        8763 non-null   uint8
#  61  Seville_pressure_sp9        8763 non-null   uint8
# dtypes: datetime64[ns](1), float64(28), uint8(33)
# memory usage: 2.3 MB

# %%
improved_df_2.head()
# Out:
#                  time  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# 0 2015-01-01 03:00:00           0.666667             0.0             0.666667
# 1 2015-01-01 06:00:00           0.333333             0.0             1.666667
# 2 2015-01-01 09:00:00           1.000000             0.0             1.000000
# 3 2015-01-01 12:00:00           1.000000             0.0             1.000000
# 4 2015-01-01 15:00:00           1.000000             0.0             1.000000
#
#    Seville_humidity  Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  \
# 0         74.333333        64.000000           1.000000       223.333333
# 1         78.333333        64.666667           1.000000       221.000000
# 2         71.333333        64.333333           1.000000       214.333333
# 3         65.333333        56.333333           1.000000       199.666667
# 4         59.000000        57.000000           0.333333       185.000000
#
#    Barcelona_wind_speed  Barcelona_wind_deg  ...  Seville_pressure_sp23  \
# 0              6.333333           42.666667  ...                      0
# 1              4.000000          139.000000  ...                      0
# 2              2.000000          326.000000  ...                      0
# 3              2.333333          273.000000  ...                      0
# 4              4.333333          260.000000  ...                      0
#
#    Seville_pressure_sp24  Seville_pressure_sp25  Seville_pressure_sp3  \
# 0                      0                      1                     0
# 1                      0                      1                     0
# 2                      0                      1                     0
# 3                      0                      1                     0
# 4                      0                      1                     0
#
#    Seville_pressure_sp4  Seville_pressure_sp5  Seville_pressure_sp6  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    Seville_pressure_sp7  Seville_pressure_sp8  Seville_pressure_sp9
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
# [5 rows x 62 columns]

# %%
def split_datetime_col(df, col):  
    new_df = df.copy()
    new_df['year'] = new_df[col].dt.year
    new_df['month'] = new_df[col].dt.month
    new_df['week'] = new_df[col].dt.week
    new_df['day'] = new_df[col].dt.day
    new_df['hour'] = new_df[col].dt.hour
    return new_df
improved_df_2 = split_datetime_col(improved_df_2, 'time')
improved_df_2.head()
# Out:
#                  time  Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  \
# 0 2015-01-01 03:00:00           0.666667             0.0             0.666667
# 1 2015-01-01 06:00:00           0.333333             0.0             1.666667
# 2 2015-01-01 09:00:00           1.000000             0.0             1.000000
# 3 2015-01-01 12:00:00           1.000000             0.0             1.000000
# 4 2015-01-01 15:00:00           1.000000             0.0             1.000000
#
#    Seville_humidity  Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  \
# 0         74.333333        64.000000           1.000000       223.333333
# 1         78.333333        64.666667           1.000000       221.000000
# 2         71.333333        64.333333           1.000000       214.333333
# 3         65.333333        56.333333           1.000000       199.666667
# 4         59.000000        57.000000           0.333333       185.000000
#
#    Barcelona_wind_speed  Barcelona_wind_deg  ...  Seville_pressure_sp5  \
# 0              6.333333           42.666667  ...                     0
# 1              4.000000          139.000000  ...                     0
# 2              2.000000          326.000000  ...                     0
# 3              2.333333          273.000000  ...                     0
# 4              4.333333          260.000000  ...                     0
#
#    Seville_pressure_sp6  Seville_pressure_sp7  Seville_pressure_sp8  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    Seville_pressure_sp9  year  month  week  day  hour
# 0                     0  2015      1     1    1     3
# 1                     0  2015      1     1    1     6
# 2                     0  2015      1     1    1     9
# 3                     0  2015      1     1    1    12
# 4                     0  2015      1     1    1    15
#
# [5 rows x 67 columns]

# %% [markdown]
# ### Modeling with Ridge Regression

# %%
# Drop time for both data set
improved_df_no_time = improved_df.drop('time', axis=1)
improved_df_2_no_time = improved_df_2.drop('time', axis=1)
improved_df_2_no_time.head()
# Out:
#    Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0           0.666667             0.0             0.666667         74.333333
# 1           0.333333             0.0             1.666667         78.333333
# 2           1.000000             0.0             1.000000         71.333333
# 3           1.000000             0.0             1.000000         65.333333
# 4           1.000000             0.0             1.000000         59.000000
#
#    Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0        64.000000           1.000000       223.333333              6.333333
# 1        64.666667           1.000000       221.000000              4.000000
# 2        64.333333           1.000000       214.333333              2.000000
# 3        56.333333           1.000000       199.666667              2.333333
# 4        57.000000           0.333333       185.000000              4.333333
#
#    Barcelona_wind_deg  Seville_wind_speed  ...  Seville_pressure_sp5  \
# 0           42.666667            3.333333  ...                     0
# 1          139.000000            3.333333  ...                     0
# 2          326.000000            2.666667  ...                     0
# 3          273.000000            4.000000  ...                     0
# 4          260.000000            3.000000  ...                     0
#
#    Seville_pressure_sp6  Seville_pressure_sp7  Seville_pressure_sp8  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    Seville_pressure_sp9  year  month  week  day  hour
# 0                     0  2015      1     1    1     3
# 1                     0  2015      1     1    1     6
# 2                     0  2015      1     1    1     9
# 3                     0  2015      1     1    1    12
# 4                     0  2015      1     1    1    15
#
# [5 rows x 66 columns]

# %%
# Split data into predictors and response
X = improved_df_no_time.drop('load_shortfall_3h', axis=1)
y = improved_df_no_time['load_shortfall_3h']
X_2 = improved_df_2_no_time.drop('load_shortfall_3h', axis=1)
y_2 = improved_df_2_no_time['load_shortfall_3h']
X_2.head()
# Out:
#    Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0           0.666667             0.0             0.666667         74.333333
# 1           0.333333             0.0             1.666667         78.333333
# 2           1.000000             0.0             1.000000         71.333333
# 3           1.000000             0.0             1.000000         65.333333
# 4           1.000000             0.0             1.000000         59.000000
#
#    Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0        64.000000           1.000000       223.333333              6.333333
# 1        64.666667           1.000000       221.000000              4.000000
# 2        64.333333           1.000000       214.333333              2.000000
# 3        56.333333           1.000000       199.666667              2.333333
# 4        57.000000           0.333333       185.000000              4.333333
#
#    Barcelona_wind_deg  Seville_wind_speed  ...  Seville_pressure_sp5  \
# 0           42.666667            3.333333  ...                     0
# 1          139.000000            3.333333  ...                     0
# 2          326.000000            2.666667  ...                     0
# 3          273.000000            4.000000  ...                     0
# 4          260.000000            3.000000  ...                     0
#
#    Seville_pressure_sp6  Seville_pressure_sp7  Seville_pressure_sp8  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    Seville_pressure_sp9  year  month  week  day  hour
# 0                     0  2015      1     1    1     3
# 1                     0  2015      1     1    1     6
# 2                     0  2015      1     1    1     9
# 3                     0  2015      1     1    1    12
# 4                     0  2015      1     1    1    15
#
# [5 rows x 65 columns]

# %%
# Import scaler method from sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Create scaler object
scaler = StandardScaler()

# %%
# Create scaled version of the predictors (there is no need to scale the response)
X_scaled = scaler.fit_transform(X)
X_scaled_2 = scaler.fit_transform(X_2)

# %%
# Convert the scaled predictor values into a dataframe
X_standardise = pd.DataFrame(X_scaled,columns=X.columns)
X_standardise_2 = pd.DataFrame(X_scaled_2,columns=X_2.columns)
X_standardise_2.head()
# Out:
#    Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0          -0.950708       -0.362123            -0.796169          0.516117
# 1          -1.130863       -0.362123            -0.381412          0.692953
# 2          -0.770554       -0.362123            -0.657917          0.383491
# 3          -0.770554       -0.362123            -0.657917          0.118238
# 4          -0.770554       -0.362123            -0.657917         -0.161751
#
#    Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0         0.270621          -0.501451         0.630823              1.932284
# 1         0.298017          -0.501451         0.607959              0.630270
# 2         0.284319          -0.501451         0.542632             -0.485743
# 3        -0.044439          -0.501451         0.398912             -0.299741
# 4        -0.017043          -0.894581         0.255192              0.816272
#
#    Barcelona_wind_deg  Seville_wind_speed  ...  Seville_pressure_sp5  \
# 0           -1.660205            0.542975  ...             -0.210555
# 1           -0.578686            0.542975  ...             -0.210555
# 2            1.520733            0.144442  ...             -0.210555
# 3            0.925711            0.941509  ...             -0.210555
# 4            0.779762            0.343708  ...             -0.210555
#
#    Seville_pressure_sp6  Seville_pressure_sp7  Seville_pressure_sp8  \
# 0             -0.221833             -0.142332             -0.223808
# 1             -0.221833             -0.142332             -0.223808
# 2             -0.221833             -0.142332             -0.223808
# 3             -0.221833             -0.142332             -0.223808
# 4             -0.221833             -0.142332             -0.223808
#
#    Seville_pressure_sp9      year     month      week       day      hour
# 0             -0.146043 -1.226179 -1.602429 -1.709703 -1.675368 -1.090901
# 1             -0.146043 -1.226179 -1.602429 -1.709703 -1.675368 -0.654451
# 2             -0.146043 -1.226179 -1.602429 -1.709703 -1.675368 -0.218001
# 3             -0.146043 -1.226179 -1.602429 -1.709703 -1.675368  0.218449
# 4             -0.146043 -1.226179 -1.602429 -1.709703 -1.675368  0.654899
#
# [5 rows x 65 columns]

# %%
X_standardise.head()
# Out:
#    Madrid_wind_speed  Bilbao_rain_1h  Valencia_wind_speed  Seville_humidity  \
# 0          -0.950708       -0.362123            -0.796169          0.516117
# 1          -1.130863       -0.362123            -0.381412          0.692953
# 2          -0.770554       -0.362123            -0.657917          0.383491
# 3          -0.770554       -0.362123            -0.657917          0.118238
# 4          -0.770554       -0.362123            -0.657917         -0.161751
#
#    Madrid_humidity  Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  \
# 0         0.270621          -0.501451         0.630823              1.932284
# 1         0.298017          -0.501451         0.607959              0.630270
# 2         0.284319          -0.501451         0.542632             -0.485743
# 3        -0.044439          -0.501451         0.398912             -0.299741
# 4        -0.017043          -0.894581         0.255192              0.816272
#
#    Barcelona_wind_deg  Seville_wind_speed  ...  Seville_pressure_sp23  \
# 0           -1.660205            0.542975  ...              -0.200604
# 1           -0.578686            0.542975  ...              -0.200604
# 2            1.520733            0.144442  ...              -0.200604
# 3            0.925711            0.941509  ...              -0.200604
# 4            0.779762            0.343708  ...              -0.200604
#
#    Seville_pressure_sp24  Seville_pressure_sp25  Seville_pressure_sp3  \
# 0              -0.220129               4.513665             -0.191182
# 1              -0.220129               4.513665             -0.191182
# 2              -0.220129               4.513665             -0.191182
# 3              -0.220129               4.513665             -0.191182
# 4              -0.220129               4.513665             -0.191182
#
#    Seville_pressure_sp4  Seville_pressure_sp5  Seville_pressure_sp6  \
# 0             -0.219843             -0.210555             -0.221833
# 1             -0.219843             -0.210555             -0.221833
# 2             -0.219843             -0.210555             -0.221833
# 3             -0.219843             -0.210555             -0.221833
# 4             -0.219843             -0.210555             -0.221833
#
#    Seville_pressure_sp7  Seville_pressure_sp8  Seville_pressure_sp9
# 0             -0.142332             -0.223808             -0.146043
# 1             -0.142332             -0.223808             -0.146043
# 2             -0.142332             -0.223808             -0.146043
# 3             -0.142332             -0.223808             -0.146043
# 4             -0.142332             -0.223808             -0.146043
#
# [5 rows x 60 columns]

# %%
# Import the ridge regression module from sklearn
from sklearn.linear_model import Ridge

# %%
# Create ridge model
ridge = Ridge()
ridge_2 = Ridge()

# %%
# Train the model
ridge.fit(X_standardise, y)
# Out:
# Ridge()

# %%
ridge_2.fit(X_standardise_2, y_2)
# Out:
# Ridge()

# %% [markdown]
# ### Test data set

# %%
#Load train data
df_test = pd.read_csv("df_test.csv", index_col=0)

# %%
clean_test_df = replace_null_with_mean(df_test, "Valencia_pressure")
clean_test_df['Valencia_pressure'].isna().sum()
# Out:
# 0

# %%
# Remove columns that will generally not affect the response from domain research of renewable energy 
cols_not_needed = ('clouds_all', 'weather_id', 'temp','temp_min')
clean_test_df = drop_columns(clean_test_df, cols_not_needed)
clean_test_df.shape
# Out:
# (2920, 30)

# %%
clean_test_df['time'] = conver_time(clean_test_df, 'time')
clean_test_df.head()
# Out:
#                     time  Madrid_wind_speed Valencia_wind_deg  Bilbao_rain_1h  \
# 8763 2018-01-01 00:00:00           5.000000           level_8             0.0
# 8764 2018-01-01 03:00:00           4.666667           level_8             0.0
# 8765 2018-01-01 06:00:00           2.333333           level_7             0.0
# 8766 2018-01-01 09:00:00           2.666667           level_7             0.0
# 8767 2018-01-01 12:00:00           4.000000           level_7             0.0
#
#       Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 8763             5.000000         87.000000        71.333333
# 8764             5.333333         89.000000        78.000000
# 8765             5.000000         89.000000        89.666667
# 8766             5.333333         93.333333        82.666667
# 8767             8.666667         65.333333        64.000000
#
#       Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  ...  \
# 8763           3.000000       193.333333              4.000000  ...
# 8764           3.666667       143.333333              4.666667  ...
# 8765           2.333333       130.000000              4.000000  ...
# 8766           5.666667       196.666667              2.333333  ...
# 8767          10.666667       233.333333              4.666667  ...
#
#       Valencia_snow_3h  Bilbao_pressure  Valencia_pressure Seville_temp_max  \
# 8763                 0      1025.666667        1013.148351       284.483333
# 8764                 0      1026.666667        1013.148351       282.483333
# 8765                 0      1025.333333        1013.148351       280.816667
# 8766                 0      1025.000000        1013.148351       281.150000
# 8767                 0      1022.333333        1013.148351       287.150000
#
#       Madrid_pressure  Valencia_temp_max  Valencia_humidity  \
# 8763      1030.000000         287.483333          46.333333
# 8764      1030.333333         284.150000          53.666667
# 8765      1030.666667         282.816667          42.000000
# 8766      1032.333333         283.483333          45.000000
# 8767      1032.333333         287.150000          41.000000
#
#       Barcelona_temp_max  Madrid_temp_max  Bilbao_temp_max
# 8763          287.816667       280.816667       285.150000
# 8764          284.816667       280.483333       284.150000
# 8765          284.483333       276.483333       282.150000
# 8766          284.150000       277.150000       284.483333
# 8767          287.483333       281.150000       286.816667
#
# [5 rows x 30 columns]

# %%
clean_test_df_copy = object_converter(clean_test_df)
clean_test_df_copy_2 = clean_test_df_copy.copy() # Create a copy of the dataset, to enable modeling with two different dataset
clean_test_df_copy_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2920 entries, 8763 to 11682
# Data columns (total 61 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   time                        2920 non-null   datetime64[ns]
#  1   Madrid_wind_speed           2920 non-null   float64
#  2   Bilbao_rain_1h              2920 non-null   float64
#  3   Valencia_wind_speed         2920 non-null   float64
#  4   Seville_humidity            2920 non-null   float64
#  5   Madrid_humidity             2920 non-null   float64
#  6   Bilbao_wind_speed           2920 non-null   float64
#  7   Bilbao_wind_deg             2920 non-null   float64
#  8   Barcelona_wind_speed        2920 non-null   float64
#  9   Barcelona_wind_deg          2920 non-null   float64
#  10  Seville_wind_speed          2920 non-null   float64
#  11  Barcelona_rain_1h           2920 non-null   float64
#  12  Seville_rain_1h             2920 non-null   float64
#  13  Bilbao_snow_3h              2920 non-null   int64
#  14  Barcelona_pressure          2920 non-null   float64
#  15  Seville_rain_3h             2920 non-null   float64
#  16  Madrid_rain_1h              2920 non-null   float64
#  17  Barcelona_rain_3h           2920 non-null   float64
#  18  Valencia_snow_3h            2920 non-null   int64
#  19  Bilbao_pressure             2920 non-null   float64
#  20  Valencia_pressure           2920 non-null   float64
#  21  Seville_temp_max            2920 non-null   float64
#  22  Madrid_pressure             2920 non-null   float64
#  23  Valencia_temp_max           2920 non-null   float64
#  24  Valencia_humidity           2920 non-null   float64
#  25  Barcelona_temp_max          2920 non-null   float64
#  26  Madrid_temp_max             2920 non-null   float64
#  27  Bilbao_temp_max             2920 non-null   float64
#  28  Valencia_wind_deg_level_10  2920 non-null   uint8
#  29  Valencia_wind_deg_level_2   2920 non-null   uint8
#  30  Valencia_wind_deg_level_3   2920 non-null   uint8
#  31  Valencia_wind_deg_level_4   2920 non-null   uint8
#  32  Valencia_wind_deg_level_5   2920 non-null   uint8
#  33  Valencia_wind_deg_level_6   2920 non-null   uint8
#  34  Valencia_wind_deg_level_7   2920 non-null   uint8
#  35  Valencia_wind_deg_level_8   2920 non-null   uint8
#  36  Valencia_wind_deg_level_9   2920 non-null   uint8
#  37  Seville_pressure_sp10       2920 non-null   uint8
#  38  Seville_pressure_sp11       2920 non-null   uint8
#  39  Seville_pressure_sp12       2920 non-null   uint8
#  40  Seville_pressure_sp13       2920 non-null   uint8
#  41  Seville_pressure_sp14       2920 non-null   uint8
#  42  Seville_pressure_sp15       2920 non-null   uint8
#  43  Seville_pressure_sp16       2920 non-null   uint8
#  44  Seville_pressure_sp17       2920 non-null   uint8
#  45  Seville_pressure_sp18       2920 non-null   uint8
#  46  Seville_pressure_sp19       2920 non-null   uint8
#  47  Seville_pressure_sp2        2920 non-null   uint8
#  48  Seville_pressure_sp20       2920 non-null   uint8
#  49  Seville_pressure_sp21       2920 non-null   uint8
#  50  Seville_pressure_sp22       2920 non-null   uint8
#  51  Seville_pressure_sp23       2920 non-null   uint8
#  52  Seville_pressure_sp24       2920 non-null   uint8
#  53  Seville_pressure_sp25       2920 non-null   uint8
#  54  Seville_pressure_sp3        2920 non-null   uint8
#  55  Seville_pressure_sp4        2920 non-null   uint8
#  56  Seville_pressure_sp5        2920 non-null   uint8
#  57  Seville_pressure_sp6        2920 non-null   uint8
#  58  Seville_pressure_sp7        2920 non-null   uint8
#  59  Seville_pressure_sp8        2920 non-null   uint8
#  60  Seville_pressure_sp9        2920 non-null   uint8
# dtypes: datetime64[ns](1), float64(25), int64(2), uint8(33)
# memory usage: 755.7 KB

# %%
clean_test_df_copy_2_time = split_datetime_col(clean_test_df_copy_2, 'time')
clean_test_df_copy_2_time.head()
# Out:
#                     time  Madrid_wind_speed  Bilbao_rain_1h  \
# 8763 2018-01-01 00:00:00           5.000000             0.0
# 8764 2018-01-01 03:00:00           4.666667             0.0
# 8765 2018-01-01 06:00:00           2.333333             0.0
# 8766 2018-01-01 09:00:00           2.666667             0.0
# 8767 2018-01-01 12:00:00           4.000000             0.0
#
#       Valencia_wind_speed  Seville_humidity  Madrid_humidity  \
# 8763             5.000000         87.000000        71.333333
# 8764             5.333333         89.000000        78.000000
# 8765             5.000000         89.000000        89.666667
# 8766             5.333333         93.333333        82.666667
# 8767             8.666667         65.333333        64.000000
#
#       Bilbao_wind_speed  Bilbao_wind_deg  Barcelona_wind_speed  \
# 8763           3.000000       193.333333              4.000000
# 8764           3.666667       143.333333              4.666667
# 8765           2.333333       130.000000              4.000000
# 8766           5.666667       196.666667              2.333333
# 8767          10.666667       233.333333              4.666667
#
#       Barcelona_wind_deg  ...  Seville_pressure_sp5  Seville_pressure_sp6  \
# 8763          176.666667  ...                     0                     0
# 8764          266.666667  ...                     0                     0
# 8765          263.333333  ...                     0                     0
# 8766           86.666667  ...                     0                     0
# 8767          283.333333  ...                     0                     0
#
#       Seville_pressure_sp7  Seville_pressure_sp8  Seville_pressure_sp9  year  \
# 8763                     0                     0                     0  2018
# 8764                     0                     0                     0  2018
# 8765                     0                     0                     0  2018
# 8766                     0                     0                     0  2018
# 8767                     0                     0                     0  2018
#
#       month  week  day  hour
# 8763      1     1    1     0
# 8764      1     1    1     3
# 8765      1     1    1     6
# 8766      1     1    1     9
# 8767      1     1    1    12
#
# [5 rows x 66 columns]

# %%
predict_test_data_time = clean_test_df['time']
predict_test_data_time
# Out:
# 8763    2018-01-01 00:00:00
# 8764    2018-01-01 03:00:00
# 8765    2018-01-01 06:00:00
# 8766    2018-01-01 09:00:00
# 8767    2018-01-01 12:00:00
#                 ...
# 11678   2018-12-31 09:00:00
# 11679   2018-12-31 12:00:00
# 11680   2018-12-31 15:00:00
# 11681   2018-12-31 18:00:00
# 11682   2018-12-31 21:00:00
# Name: time, Length: 2920, dtype: datetime64[ns]

# %%
## Drop the time colunm for both data set
clean_test_df_copy = clean_test_df_copy.drop('time', axis =1)
clean_test_df_copy_2_time = clean_test_df_copy_2_time.drop('time', axis =1)

# %%
predict_result = ridge.predict(clean_test_df_copy)
predict_result
# Out:
# array([124119.77890401, 106200.60842433, 112186.45445591, ...,
#        183954.46418979, 180489.13872312, 116271.39097973])

# %%
my_dict = {
    'time': predict_test_data_time,
    'load_shortfall_3h':predict_result
}

# %%
new_pandas = pd.DataFrame(my_dict)
new_pandas.shape
# Out:
# (2920, 2)

# %%
new_pandas.to_csv('file_4.csv',index=False)
